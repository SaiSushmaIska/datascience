# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv("HREmployee.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.plot(x="Attrition", y="PerformanceRating", kind="bar")
# Out:
# <Axes: xlabel='Attrition'>

# %%
df.plot(x="Attrition", y="PerformanceRating", kind="bar", logy=True)
# Out:
# <Axes: xlabel='Attrition'>

# %%
df.plot(x="Attrition", y="PercentSalaryHike", kind="bar")
# Out:
# <Axes: xlabel='Attrition'>

# %%
df.plot(x="Attrition", y="HourlyRate", kind="bar")
# Out:
# <Axes: xlabel='Attrition'>

# %%
df.plot(x="Attrition", y="HourlyRate", kind="bar", logy=True)
# Out:
# <Axes: xlabel='Attrition'>

# %%
sn.histplot(df.Attrition, kde=True)
# Out:
# <Axes: xlabel='Attrition', ylabel='Count'>

# %%
df.plot(x="JobLevel", y="PercentSalaryHike", kind="scatter")
# Out:
# <Axes: xlabel='JobLevel', ylabel='PercentSalaryHike'>

# %%
df.plot(x="JobLevel", y="PercentSalaryHike", kind="scatter", logy=True)
# Out:
# <Axes: xlabel='JobLevel', ylabel='PercentSalaryHike'>

# %%
df.plot(x="JobLevel", y="PercentSalaryHike", kind="bar")
# Out:
# <Axes: xlabel='JobLevel'>

# %%
df.plot(x="JobLevel", y="PercentSalaryHike", kind="box")
# Out:
# <Axes: >

# %%
df.plot(x="JobLevel", y="HourlyRate", kind="bar")
# Out:
# <Axes: xlabel='JobLevel'>

# %%
df.plot(x="JobLevel", y="HourlyRate", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="JobLevel", y="HourlyRate", kind="box")
# Out:
# <Axes: >

# %%
df.plot(x="JobLevel", y="JobSatisfaction", kind="bar")
# Out:
# <Axes: xlabel='JobLevel'>

# %%
df.plot(x="JobLevel", y="JobSatisfaction", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="Age", y="EmployeeCount", kind="bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df.plot(x="Age", y="EmployeeCount", kind="bar", logy=True)
# Out:
# <Axes: xlabel='Age'>

# %%
df.plot(x="Age", y="EmployeeCount", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="Age", y="EmployeeCount", kind="scatter")
# Out:
# <Axes: xlabel='Age', ylabel='EmployeeCount'>

# %%
df.plot(x="PercentSalaryHike", y="PerformanceRating", kind="bar")
# Out:
# <Axes: xlabel='PercentSalaryHike'>

# %%
df.plot(x="PercentSalaryHike", y="PerformanceRating", kind="bar", logy=True)
# Out:
# <Axes: xlabel='PercentSalaryHike'>

# %%
df.plot(x="PercentSalaryHike", y="PerformanceRating", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
df.plot(x="WorkLifeBalance", y="YearsAtCompany", kind="scatter")
# Out:
# <Axes: xlabel='WorkLifeBalance', ylabel='YearsAtCompany'>

# %%
df.plot(x="WorkLifeBalance", y="YearsAtCompany", kind="bar")
# Out:
# <Axes: xlabel='WorkLifeBalance'>

# %%
df.plot(x="TotalWorkingYears", y="PerformanceRating", kind="bar")
# Out:
# <Axes: xlabel='TotalWorkingYears'>

# %%
df.plot(x="TotalWorkingYears", y="PerformanceRating", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x="TotalWorkingYears", y="PerformanceRating", kind="pie")
# Out:
# <Axes: ylabel='PerformanceRating'>

# %%
x=np.random.normal(170,30,777)
plt.pie(x)
plt.show()

# %%
df.plot(x="MonthlyRate", y="PercentSalaryHike", kind="bar")
# Out:
# <Axes: xlabel='MonthlyRate'>

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.tail(-3)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...
